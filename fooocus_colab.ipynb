# %%
# ============================================================
# Fooocus - Realistic Edition (LUSTIFY-v2.0 by TheImposterImposters)
# Repo: https://github.com/moontasirabtahee/Fooocus
# ============================================================
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/moontasirabtahee/Fooocus.git
# %cd /content/Fooocus
# Launches with realistic preset -> downloads lustifySDXLNSFWSFW_v20.safetensors (~6.9GB)
# To switch preset: replace '--preset realistic' with '--preset anime' or remove for default
# !python entry_with_update.py --share --always-high-vram --preset realistic
